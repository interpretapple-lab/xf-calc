# %%
from fuzzyCalc.visualization.fuzzyInterfazController import *

# %%
fuzzy_operation = "around(4) * around(2) * around(3) * around(3)"
confidence = "Medium"

# %%
notebookCalculator(fuzzy_operation, confidence)

# %%
fuzzy_operation = "atLeast(6) + around(7)"
confidence = "Low"

# %%
notebookCalculator(fuzzy_operation, confidence)

# %%
fuzzy_operation = "between(6, 9) - around(5)"
confidence = "High"

# %%
notebookCalculator(fuzzy_operation, confidence)
